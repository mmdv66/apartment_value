# %%
import pandas as pd

# %%
df= pd.read_csv('../data/dataset.csv')
df.head()
# Out:
#      flat_id                                                url  \
# 0  324549697  https://www.cian.ru/sale/flat/324549697/?conte...
# 1  320335475  https://www.cian.ru/sale/flat/320335475/?conte...
# 2  326880398  https://www.cian.ru/sale/flat/326880398/?conte...
# 3  326438271  https://www.cian.ru/sale/flat/326438271/?conte...
# 4  323005752  https://www.cian.ru/sale/flat/323005752/?conte...
#
#             scraped_at     price_rub  price_per_m2  rooms  is_studio  \
# 0  2026-03-22 13:13:00  1.550000e+09     1132213.0    3.0          0
# 1  2026-03-22 13:13:01           NaN           NaN    2.0          0
# 2  2026-03-22 13:13:08  8.250000e+08      996377.0    3.0          0
# 3  2026-03-22 13:13:07  3.100000e+08      534483.0    2.0          0
# 4  2026-03-22 13:13:15  6.167388e+08      855394.0    2.0          0
#
#    total_area  living_area  kitchen_area  ...  image_count_local  \
# 0       136.9          NaN          14.9  ...                  0
# ...

# %%
len(df['district'])
# Out:
# 28

# %%
(list(df.columns))
# Out:
# ['flat_id',
#  'url',
#  'scraped_at',
#  'price_rub',
#  'price_per_m2',
#  'rooms',
#  'is_studio',
#  'total_area',
#  'living_area',
#  'kitchen_area',
#  'living_ratio',
#  'kitchen_ratio',
#  'non_living_area',
#  'floor',
#  'floors_total',
#  'is_first_floor',
#  'is_last_floor',
#  'floor_ratio',
#  'floors_above',
#  'build_year',
#  'building_age',
#  'building_type',
#  'building_type_cat',
#  'building_type_code',
#  'ceiling_height',
#  'renovation',
#  'renovation_cat',
#  'has_elevator_bin',
#  'has_parking_obj',
#  'has_balcony_obj',
#  'bathroom_separate',
#  'elevator',
#  'parking_type',
#  'balcony_type',
#  'bathroom',
#  'heating',
#  'windows',
#  'desc_len',
#  'desc_word_count',
#  'has_balcony',
#  'has_loggia',
#  'has_parking',
#  'has_furniture',
#  'has_renovated',
#  'has_mortgage',
#  'has_new_building',
#  'has_view',
#  'has_alarm',
#  'metro_station',
#  'metro_minutes',
#  'metro_by_foot',
#  'district',
#  'address',
#  'image_count',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 50 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   flat_id            28 non-null     int64
#  1   url                28 non-null     object
#  2   scraped_at         28 non-null     object
#  3   price_rub          18 non-null     float64
#  4   price_per_m2       18 non-null     float64
#  5   rooms              27 non-null     float64
#  6   is_studio          28 non-null     int64
#  7   total_area         28 non-null     float64
#  8   living_area        18 non-null     float64
#  9   kitchen_area       18 non-null     float64
#  10  living_ratio       18 non-null     float64
#  11  kitchen_ratio      18 non-null     float64
#  12  non_living_area    18 non-null     float64
#  13  floor              28 non-null     int64
#  14  floors_total       28 non-null     int64
#  15  is_first_floor     28 non-null     int64
# ...

# %%
# Out:
# ['{"общая площадь": "137\xa0м²", "жилая площадь": "74\xa0м²", "площадь кухни": "15\xa0м²", "этаж": "6 из 8"}', '{"общая площадь": "76\xa0м²", "жилая площадь": "27,3\xa0м²", "площадь кухни": "22,4\xa0м²", "этаж": "2 из 9", "год сдачи": "2027", "дом": "Не сдан", "отделка": "Без отделки"}', '{"общая площадь": "118,5\xa0м²", "площадь кухни": "23,4\xa0м²", "этаж": "15 из 22", "год постройки": "2007"}']

# %%
# Out:
# {'общая площадь': '137\xa0м²', 'жилая площадь': '74\xa0м²', 'площадь кухни': '15\xa0м²', 'этаж': '6 из 8'}
#
# {'общая площадь': '76\xa0м²', 'жилая площадь': '27,3\xa0м²', 'площадь кухни': '22,4\xa0м²', 'этаж': '2 из 9', 'год сдачи': '2027', 'дом': 'Не сдан', 'отделка': 'Без отделки'}
#
# {'общая площадь': '118,5\xa0м²', 'площадь кухни': '23,4\xa0м²', 'этаж': '15 из 22', 'год постройки': '2007'}
